# %% [markdown]
# ## <b> Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
#
# ## <b>This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. </b>
#
# ## <b> Explore and analyze the data to discover important factors that govern the bookings. </b>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Each Row in our dataset contains information for a particular instance of booking. Now Let's explain what every column in our dataset contains.
#
#  1.  hotel - Hotel Name
#  2.   is_canceled - If a booking was canceled or not.
# *   0 - Booking was not cancelled.
# *   1 - Booking was cancelled.
#
#
#  3.   lead_time - Waiting time(in days) between the time of booking and time of arrival.
#  4.   arrival_date_year - Year of arrival.
#  5.   arrival_date_month - Month of arrival.
#  6.   arrival_date_week_number - Week number of arrival.
#  7.   arrival_date_day_of_month - Day number of arrival.
#  8.   stays_in_weekend_nights - No. of weekend nights that the customer stayed for.
#  9.   stays_in_week_nights - No. of week nights that the customer stayed for.
#  10.   adults - No. of adults staying.
#  11.  children - No. of children staying.
#  12.  babies - No. of babies staying.
#  13.  meal - Meal type chosen by the customer.
# *   SC - Self catering.(No meals included)
# *   BB - Bed and Breakfast
# *   HB - Half Board(Breakfast and Lunch/ Breakfast and Dinner)
# *   FB - Full Board(Breakfast + Lunch + Dinner)
#
#
#  14.  country - Country of origin of the customer.
#  15.  market_segment - Market segment to which customer belongs.
#  16.  distribution_channel - Distribution channel through which booking was made.
#  17.  is_repeated_guest - Whether or not a customer has stayed in the same hotel before.
# *   0 - Not a repeated guest
# *   1 - A repeated guest(Has stayed in the same hotel before)
#
#  18.  previous_cancellations - Previous cancellations made by the customer.
#  19.  previous_bookings_not_canceled - Previous bookings that haven't been canceled.
#  20.  reserved_room_type - Type of the room reserved.
#  21.  assigned_room_type - Type of the room assigned.
#  22.  booking_changes - No. of booking changes made.
#  23.  deposit_type - Type of deposit made.
#  24.  agent - Unique ID of Agent through which booking is made.
#  25.  company -  Unique ID of Company through which booking was made.
#  26.  days_in_waiting_list - number of days spent on the waiting list by customer.
#  27.  customer_type - Type of customer.
#  28.  adr - Average daily rate.
#  29.  required_car_parking_spaces - No. of car parking spaces required by the customer.
#  30.  total_of_special_requests - Total number of special requests made by the customers.
#  31.  reservation_status - Status of reservation.
#  32.  reservation_status_date - Date of change in reservation status.

# %%
import pandas as pd
# df=pd.read_csv("C:\\Users\Mokshda Sharma\Desktop\projects\hotel_booking.csv\hotel_booking.csv")
df=pd.read_csv("C:\\Users\Mokshda Sharma\Desktop\My Projects\EDA_hotel_booking\hotel_booking.csv\hotel_booking.csv")
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\M'
# <>:3: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\Mokshda Sharma\AppData\Local\Temp\ipykernel_23560\3592306769.py:3: SyntaxWarning: invalid escape sequence '\M'
#   df=pd.read_csv("C:\\Users\Mokshda Sharma\Desktop\My Projects\EDA_hotel_booking\hotel_booking.csv\hotel_booking.csv")

# %%
# Checking how the dataframe looks.
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
df.shape
# Out:
# (119390, 36)

# %%
ndf = df.copy()

# %%
ndf.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
count_0 = ndf['is_canceled'].value_counts()[0]
count_1 = ndf['is_canceled'].value_counts()[1]

# %%
#no. of booking that were cancelled
count_1
# Out:
# 44224

# %%
#booking that were not cancelled
count_0
# Out:
# 75166

# %%
#Melting the dataset on columns of hotel and lead_time
newdf = pd.melt(ndf,id_vars=['hotel'], value_vars=['lead_time'],var_name='hotel2', value_name='leads')
newdf
# Out:
#                hotel     hotel2  leads
# 0       Resort Hotel  lead_time    342
# 1       Resort Hotel  lead_time    737
# 2       Resort Hotel  lead_time      7
# 3       Resort Hotel  lead_time     13
# 4       Resort Hotel  lead_time     14
# ...              ...        ...    ...
# 119385    City Hotel  lead_time     23
# 119386    City Hotel  lead_time    102
# 119387    City Hotel  lead_time     34
# 119388    City Hotel  lead_time    109
# 119389    City Hotel  lead_time    205
#
# [119390 rows x 3 columns]

# %%
#drop irrelevant columns
ndf=df.drop(['agent','company','email','phone-number','credit_card'],axis=1)
ndf
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
#checking for types of citomers who booked the hotel
n = (pd.unique(ndf['customer_type']))
n
# Out:
# array(['Transient', 'Contract', 'Transient-Party', 'Group'], dtype=object)

# %%
#creating a new dataframe in which all the values are grouped on the basis of different hotels
gk=ndf.groupby('hotel')
gk.first()
# Out:
#               is_canceled  lead_time  arrival_date_year arrival_date_month  \
# hotel
# City Hotel              0          6               2015               July
# Resort Hotel            0        342               2015               July
#
#               arrival_date_week_number  arrival_date_day_of_month  \
# hotel
# City Hotel                          27                          1
# Resort Hotel                        27                          1
#
#               stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# hotel
# City Hotel                          0                     2       1       0.0
# Resort Hotel                        0                     0       2       0.0
#
#               ...  booking_changes deposit_type days_in_waiting_list  \
# hotel         ...
# City Hotel    ...                0   No Deposit                    0
# Resort Hotel  ...                3   No Deposit                    0
#
# ...

# %%
#setting the dataframe to display all the coulmns
pd.set_option('display.max.columns', None)
ndf
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
#checking for unique data in the column meal
un = (pd.unique(ndf['meal']))
un
# Out:
# array(['BB', 'FB', 'HB', 'SC', 'Undefined'], dtype=object)

# %%
#createing a dataframe with data clubbed on the basis of type of meal 
mealdf= ndf.groupby('meal').count()
mealdf
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# meal
# BB         92310        92310      92310              92310
# FB           798          798        798                798
# HB         14463        14463      14463              14463
# SC         10650        10650      10650              10650
# Undefined   1169         1169       1169               1169
#
#            arrival_date_month  arrival_date_week_number  \
# meal
# BB                      92310                     92310
# FB                        798                       798
# HB                      14463                     14463
# SC                      10650                     10650
# Undefined                1169                      1169
#
#            arrival_date_day_of_month  stays_in_weekend_nights  \
# meal
# BB                             92310                    92310
# FB                               798                      798
# ...

# %%
#different modes of depoits made while booking the hotel
nu= (pd.unique(ndf['deposit_type']))
nu
# Out:
# array(['No Deposit', 'Refundable', 'Non Refund'], dtype=object)

# %% [markdown]
# There are three types of values in deposit column i.e "no deposit", "Refundable" and "non refund".

# %%
#taking count of bookings on the basis of deposit type
ndf['deposit_type'].value_counts()
# Out:
# deposit_type
# No Deposit    104641
# Non Refund     14587
# Refundable       162
# Name: count, dtype: int64

# %%
#checking duplicate data
ndf[ndf.duplicated()]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 6645    Resort Hotel            0        322               2016
# 66833     City Hotel            1        156               2017
# 69339     City Hotel            1         35               2017
# 94208     City Hotel            0        301               2016
# 106303    City Hotel            0         48               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 6645                 June                        26
# 66833               April                        17
# 69339                 May                        22
# 94208                July                        31
# 106303           February                         8
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 6645                           22                        0
# 66833                          26                        0
# 69339                          30                        0
# ...

# %%
#dropping dulpicate data
ndf.drop_duplicates(inplace=True)

# %%
#statistical representation of the dataframe
ndf.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119385.000000  119385.000000      119385.000000
# mean        0.370415     104.008552        2016.156536
# std         0.482918     106.861536           0.707478
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119385.000000              119385.000000
# mean                  27.165440                  15.797814
# std                   13.605265                   8.780735
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
#Checking for outliers
plt.figure(figsize=(7,5))
df.boxplot()
plt.xticks(rotation=90)   
plt.title('Boxplot to detect outliers in our dataframe.', weight='bold')
# Out:
# Text(0.5, 1.0, 'Boxplot to detect outliers in our dataframe.')

# %% [markdown]
# from the above graph, it is to be noted that the colmns adr, lead time and days_in_waitng-list contains outliers

# %%
# finding and removing outliers
a=df[['adr','lead_time','days_in_waiting_list']].quantile(0.25)
b=df[['adr','lead_time','days_in_waiting_list']].quantile(0.75)
IQR=b-a
outliers = ((df[['adr','lead_time','days_in_waiting_list']] < (a - 1.5 * IQR)) | df[['adr','lead_time','days_in_waiting_list']] > (b + 1.5 * IQR))
outliers
# Out:
#           adr  lead_time  days_in_waiting_list
# 0       False      False                 False
# 1       False      False                 False
# 2       False      False                 False
# 3       False      False                 False
# 4       False      False                 False
# ...       ...        ...                   ...
# 119385  False      False                 False
# 119386  False      False                 False
# 119387  False      False                 False
# 119388  False      False                 False
# 119389  False      False                 False
#
# [119390 rows x 3 columns]

# %%
x = ndf['meal'].value_counts()
# function to add value labels
plt.title("Type of meal preferred by the Customers",weight='bold')
plt.xlabel("Types of meal available",weight='bold')
plt.ylabel("Count of each meal type",weight='bold')
plots = x.plot(kind='bar', color='purple', edgecolor='hotpink', lw=3)
for bar in plots.patches:
  plots.annotate(format(bar.get_height(), '.1f'),(bar.get_x() + bar.get_width() / 2,bar.get_height()), ha='center', va='center',
                 size=10, xytext=(0, 6),textcoords='offset points')
# for p in a.patches:
#         a.annotate(format(p.get_height(), '0.1f'), (p.get_x() + 0.1, p.get_height()+50),size=10)
# plt.legend(['Bed and Breakfast','Half Board','Self catering','Not defined','Full-Board'],fontsize="10", loc ="upper right")
plt.show()

# %% [markdown]
# majority of people prefer to take bed and breakfast, while about 20k people prefer either half board, which includes breakfast and lunch/ breakfast and dinner or self catering, which means no meals included from the hotel. least of the members either do not define their meal type or opt for full board that means they wanted to be catered with all the three meals i.e breakfast + lunch + dinner

# %%
plt.figure(figsize=(15, 6)) 
x = ndf['arrival_date_month'].value_counts() 
plt.pie(x.values, 
        labels=x.index, 
        autopct = '%1.1f%%', 
        startangle = 90,
        wedgeprops= {"edgecolor":"black", 
                     'linewidth': 1, 
                     'antialiased': True}) 
plt.xlabel('Month Name',weight='bold')
plt.ylabel('No of reseravtions',weight='bold')
plt.title('No of reservations made per month in a year',weight='bold')
plt.show()

# %% [markdown]
# above chart represents the coustomer count every month for the particular known years. The months of August and july witness the maximum customers with a value of about 11.6% AND 10.6 % respectively. This insight is governed by the fact that both the adults and childrens have their summer vacations with in the period, thus we receive maximum bookings in this particular time frame.
# further, the period of april , may and june receives near about 9% of the bookings due to relative weather conditions that are preferred mostly for the outing purposes. The booking count inspected for the months of march and september are near about 8%. The time period from november to january witness the least hotel bookings due to cold - harsh climatic conditions that are least suitable for the vacations.

# %%
plt.figure(figsize=(20, 7)) 
plots = sns.histplot(ndf['market_segment'], palette = 'spring_r', lw=3)
for bar in plots.patches:
  plots.annotate(format(bar.get_height(), '.1f'),(bar.get_x() + bar.get_width() / 2,bar.get_height()), ha='center', va='center',
                 size=10, xytext=(0, 6),textcoords='offset points')
plt.xlabel('customers belonging to a particular market type', weight= 'bold')
plt.ylabel('no of bookings made by customers belonging to a particular market type', weight= 'bold')
plt.title('Bookings made by customers belonging to a particular market type', weight= 'bold')
# Out:
# C:\Users\Mokshda Sharma\AppData\Local\Temp\ipykernel_23560\271559113.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   plots = sns.histplot(ndf['market_segment'], palette = 'spring_r', lw=3)
# Text(0.5, 1.0, 'Bookings made by customers belonging to a particular market type')

# %% [markdown]
# Majority of the clients belongs to the market sector of "online TA". More than 20k of the clients  either belongs to  "offline TA/TO" or "groups". there are hardly any client from "aviation" sector or belongs to "complementary". 10k plus clients are "direct" and nearby about 10k of the clients forms the corporate sector.

# %%
plt.figure(figsize=(20, 7)) 
plota = sns.barplot(x=ndf['hotel'], y=ndf['lead_time'], palette = 'spring_r', lw=3) 
for bar in plots.patches:
  plots.annotate(format(bar.get_height(), '.1f'),(bar.get_x() + bar.get_width() / 2,bar.get_height()), ha='center', va='center',
                 size=10, xytext=(0, 6),textcoords='offset points')
plt.ylabel('Waiting time(in days) between the time of booking and time of arrival', weight = 'bold')
plt.xlabel('hotels', weight = 'bold')
plt.title('Waiting time between the time of booking and time of arrival for each hotel', weight = 'bold')
# Out:
# C:\Users\Mokshda Sharma\AppData\Local\Temp\ipykernel_23560\3297663298.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   plota = sns.barplot(x=ndf['hotel'], y=ndf['lead_time'], palette = 'spring_r', lw=3)
# Text(0.5, 1.0, 'Waiting time between the time of booking and time of arrival for each hotel')

# %% [markdown]
# City hotel has more Waiting time(in days) between the time of booking and time of arrival than the Resort Hotel

# %%
plt.figure(figsize=(15, 5)) 
sns.scatterplot(x=ndf['market_segment'], y=ndf['lead_time'])
# Out:
# <Axes: xlabel='market_segment', ylabel='lead_time'>

# %%
plt.figure(figsize=(15, 5)) 
x = ndf['distribution_channel'].value_counts() 
plt.xlabel("booking channel", weight = 'bold')
plt.ylabel("no of bookings", weight = 'bold')
plt.title("channels opted for hotel booking", weight = 'bold')
plots = x.plot(kind='bar',color='green', edgecolor = 'blue')
for bar in plots.patches:
  plots.annotate(format(bar.get_height(), '.1f'),(bar.get_x() + bar.get_width() / 2,bar.get_height()), ha='center', va='center',
                 size=10, xytext=(0, 6),textcoords='offset points')

# %% [markdown]
# Majorly bookings are being made using "TA/TO" channel but about 20k of the clients preferred "direct" method of hotel booking while the least preferred "corporate" or "gds" merthod.

# %%
plots =sns.barplot(ndf['customer_type'])
plt.xlabel("type of customer", weight = 'bold')
plt.ylabel("no of bookings", weight = 'bold')
plt.title("type of customers booking hotels", weight = 'bold')
# for bar in plots.patches:
#   plots.annotate(format(bar.get_height(), '.1f'),(bar.get_x() + bar.get_width() / 2,bar.get_height()), ha='center', va='center',
                #  size=10, xytext=(0, 6),textcoords='offset points')
# Out:
# Text(0.5, 1.0, 'type of customers booking hotels')

# %% [markdown]
# customers majorly belongs to "Transient" type followed by "transient-party". Laest of them are either  "Contracts" or belongs to "Group"

# %%
monthly_hotelwise_df = ndf.groupby('hotel')['arrival_date_month'].value_counts().unstack().T
monthly_hotelwise_df
# Out:
# hotel               City Hotel  Resort Hotel
# arrival_date_month
# April                     7479          3609
# August                    8983          4894
# December                  4132          2648
# February                  4964          3103
# January                   3736          2193
# July                      8087          4573
# June                      7894          3044
# March                     6458          3336
# May                       8231          3559
# November                  4357          2437
# October                   7605          3555
# September                 7400          3108

# %%
# plt.figure(figsize=(15, 5)) 
x = monthly_hotelwise_df['City Hotel']
y = monthly_hotelwise_df['Resort Hotel']
monthly_hotelwise_df['total'] = monthly_hotelwise_df['City Hotel'] + monthly_hotelwise_df['Resort Hotel']
monthly_hotelwise_df.plot.bar()
plt.xlabel("Month", weight = 'bold')
plt.ylabel("no of bookings", weight = 'bold')
plt.title("bookings made in each month in a particular hotel and their total", weight = 'bold')
# Out:
# Text(0.5, 1.0, 'bookings made in each month in a particular hotel and their total')

# %% [markdown]
# City hotel had the maximum customers in month of august of 9k while the Resort hotel had maximum customers with a count of 5k in mionths of august and july, both together giving highest count in the month of august, followed by july

# %%
ndf.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name'],
#       dtype='object')

# %%
plt.figure(figsize=(15, 5)) 
x = ndf['is_canceled'].value_counts() 
plt.pie(x.values,
        labels=['Not Cancelled',' Cancelled'],
        autopct='%1.1f%%') 
plt.legend(['Not Cancelled',' Cancelled'])
plt.title("Bookings cancelled by the cutomer", weight='bold')
# Out:
# Text(0.5, 1.0, 'Bookings cancelled by the cutomer')

# %% [markdown]
# About 37% of the total bookings made are being cancelled while 63% are lef
# t uncancelled.

# %%
hotel_list = ndf['hotel'].value_counts()          
hotel_count = ndf['hotel'].value_counts().index
plt.figure(figsize = (8,5))
plt.bar(hotel_count, hotel_list,color = 'green')
plt.title('Total Number of Bookings for Each Hotel', weight = 'bold')
plt.xlabel('Hotel Type', weight = 'bold')
plt.ylabel('Reservation Count', weight = 'bold')
# Out:
# Text(0, 0.5, 'Reservation Count')

# %%
plt.figure(figsize=(15, 5)) 
x = ndf['is_repeated_guest'].value_counts() 
plt.pie(x.values, 
        labels=['Not repaeted','Repeated'], 
        autopct='%1.1f%%',
        explode=(0.1,0.2)) 
plt.legend(['Not repaeted','Repeated'])
plt.title("Guests who visited the hotel back again", weight='bold')
# Out:
# Text(0.5, 1.0, 'Guests who visited the hotel back again')

# %% [markdown]
# Among all the guest reservations made, only 3.2% of the guest really visited the hotels back again.

# %%
#creating pivot table
table = pd.pivot_table(df, values=['adults','children','babies'], index=['country'],columns=['hotel'], aggfunc="sum")
table
# Out:
#             adults                  babies                children  \
# hotel   City Hotel Resort Hotel City Hotel Resort Hotel City Hotel
# country
# ABW            5.0          NaN        0.0          NaN        0.0
# AGO          524.0         46.0        5.0          0.0       71.0
# AIA            2.0          NaN        0.0          NaN        2.0
# ALB           15.0          6.0        0.0          1.0        0.0
# AND            4.0         11.0        0.0          0.0        0.0
# ...            ...          ...        ...          ...        ...
# VGB            2.0          NaN        0.0          NaN        0.0
# VNM           13.0          4.0        0.0          0.0        0.0
# ZAF          108.0         35.0        0.0          0.0       10.0
# ZMB            2.0          2.0        0.0          0.0        0.0
# ZWE            4.0          4.0        0.0          0.0        0.0
#
#
# hotel   Resort Hotel
# country
# ABW              NaN
# AGO              6.0
# ...

# %%
corr_matrix=table.corr()
sns.heatmap(corr_matrix,  vmin=-1, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# very less no of the visitors requires parking facility which means that mostly people who visits the hotel  might be toursit type who prefers more to use cab facilities

# %%
repeated_cust = ndf.groupby('customer_type')['is_repeated_guest'].value_counts().unstack().T
repeated_cust
# Out:
# customer_type      Contract  Group  Transient  Transient-Party
# is_repeated_guest
# 0                      4043    416      86538            24578
# 1                        33    161       3073              543

# %%
sns.histplot(repeated_cust)
plt.title("type of customers who previously stayed in the same hotel", weight = 'bold')
plt.xlabel("frequency", weight = 'bold')
plt.ylabel("already styaed in the same hotel", weight = 'bold')
# Out:
# Text(0, 0.5, 'already styaed in the same hotel')

# %% [markdown]
# transient types of customer never stayed in the same hotell before, followed by the count of transient-party type of the customers. Half of the group type of the customers have already stayed int he same hotel and half of them doesn't.

# %%
ndf['previous_cancellations'].unique()
# Out:
# array([ 0,  1,  2,  3, 26, 25, 14,  4, 24, 19,  5, 21,  6, 13, 11],
#       dtype=int64)

# %%
cancellation = ndf.groupby('customer_type')['previous_cancellations'].value_counts().unstack().T
cancellation
# Out:
# customer_type           Contract  Group  Transient  Transient-Party
# previous_cancellations
# 0                         3158.0  558.0    86019.0          23166.0
# 1                          917.0   17.0     3241.0           1876.0
# 2                            1.0    2.0       95.0             18.0
# 3                            NaN    NaN       53.0             12.0
# 4                            NaN    NaN       29.0              2.0
# 5                            NaN    NaN       18.0              1.0
# 6                            NaN    NaN       22.0              NaN
# 11                           NaN    NaN       25.0             10.0
# 13                           NaN    NaN        1.0             11.0
# 14                           NaN    NaN       14.0              NaN
# 19                           NaN    NaN       19.0              NaN
# 21                           NaN    NaN        NaN              1.0
# ...

# %%
a = df[df['is_canceled']==0]['country']
a
# Out:
# 0         PRT
# 1         PRT
# 2         GBR
# 3         GBR
# 4         GBR
#          ...
# 119385    BEL
# 119386    FRA
# 119387    DEU
# 119388    GBR
# 119389    DEU
# Name: country, Length: 75166, dtype: object

# %%
top_10_countries = df[df['is_canceled']==0]['country'].value_counts()[:10].reset_index().rename(columns={'index':'country','country':'no_of_bookings'})
# top_10_countries['percentage']=(top_10_countries['no_of_bookings']/top_10_countries['no_of_bookings'].sum())*100
top_10_countries
# Out:
#   no_of_bookings  count
# 0            PRT  21071
# 1            GBR   9676
# 2            FRA   8481
# 3            ESP   6391
# 4            DEU   6069
# 5            IRL   2543
# 6            ITA   2433
# 7            BEL   1868
# 8            NLD   1717
# 9            USA   1596

# %%
x = top_10_countries['no_of_bookings']
y = top_10_countries['count']
fig, ax = plt.subplots()
ax.scatter(x, y, vmin=0, vmax=100)
plt.xlabel("countries",weight= 'bold')
plt.ylabel("total bookings made" ,weight= 'bold')
plt.title("Total booking made by top 10 countires" ,weight= 'bold')
# Out:
# C:\Users\Mokshda Sharma\AppData\Local\Temp\ipykernel_23560\2065053240.py:4: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(x, y, vmin=0, vmax=100)
# Text(0.5, 1.0, 'Total booking made by top 10 countires')

# %%
cancellation.dropna(inplace= True)
cancellation
# Out:
# customer_type           Contract  Group  Transient  Transient-Party
# previous_cancellations
# 0                         3158.0  558.0    86019.0          23166.0
# 1                          917.0   17.0     3241.0           1876.0
# 2                            1.0    2.0       95.0             18.0

# %%
ndf['country'].value_counts()
# Out:
# country
# PRT    48588
# GBR    12129
# FRA    10415
# ESP     8567
# DEU     7286
#        ...
# DJI        1
# BWA        1
# HND        1
# VGB        1
# NAM        1
# Name: count, Length: 177, dtype: int64

# %%
country = ndf.groupby('country')['distribution_channel'].value_counts().unstack().T
country
# Out:
# country               ABW    AGO  AIA  ALB  AND   ARE    ARG  ARM  ASM  ATA  \
# distribution_channel
# Corporate             NaN    5.0  NaN  2.0  NaN   NaN   11.0  1.0  NaN  NaN
# Direct                NaN  148.0  NaN  2.0  1.0   4.0   27.0  1.0  NaN  1.0
# GDS                   NaN    NaN  NaN  NaN  NaN   NaN    1.0  NaN  NaN  NaN
# TA/TO                 2.0  209.0  1.0  8.0  6.0  47.0  175.0  6.0  1.0  1.0
# Undefined             NaN    NaN  NaN  NaN  NaN   NaN    NaN  NaN  NaN  NaN
#
# country               ATF    AUS     AUT   AZE  BDI     BEL  BEN  BFA   BGD  \
# distribution_channel
# Corporate             NaN    7.0    77.0   NaN  NaN   122.0  NaN  NaN   NaN
# Direct                NaN   49.0    70.0   2.0  NaN   304.0  NaN  NaN   1.0
# GDS                   NaN    NaN     2.0   NaN  NaN     3.0  NaN  NaN   NaN
# TA/TO                 1.0  370.0  1114.0  15.0  1.0  1913.0  3.0  1.0  11.0
# Undefined             NaN    NaN     NaN   NaN  NaN     NaN  NaN  NaN   NaN
#
# ...

# %%
# country.plot.area()

# %% [markdown]
# maximum clients resides from Syc,zmb,sgp countries.

# %%
#creating pivot table
table = pd.pivot_table(df, values=['adults','children','babies'], index=['arrival_date_month'],columns=['arrival_date_year'], aggfunc="sum")
table
# Out:
#                     adults                   babies             children  \
# arrival_date_year     2015     2016     2017   2015  2016  2017     2015
# arrival_date_month
# April                  NaN   9994.0  10812.0    NaN  24.0  29.0      NaN
# August              7545.0  10351.0   9899.0   67.0  81.0  48.0    428.0
# December            5208.0   7174.0      NaN   46.0  32.0   NaN    216.0
# February               NaN   6866.0   7584.0    NaN  27.0  32.0      NaN
# January                NaN   3696.0   6328.0    NaN  23.0  25.0      NaN
# July                5423.0   9118.0  10623.0   26.0  59.0  36.0    266.0
# June                   NaN   9637.0  10716.0    NaN  41.0  30.0      NaN
# March                  NaN   8784.0   8891.0    NaN  34.0  23.0      NaN
# May                    NaN   9982.0  11557.0    NaN  32.0  40.0      NaN
# November            3714.0   7774.0      NaN   21.0  24.0   NaN     72.0
# October             8860.0  11419.0      NaN   32.0  30.0   NaN    192.0
# ...

# %%
# plt.figure(figsize=(15, 5)) 
# sns.heatmap(table ,vmin=-1, annot=True, cmap='coolwarm')
# plt.xlabel("client type(as per age group)")
# plt.ylabel("months")
# plt.title("clients arrived each month")

# %%
plots = sns.barplot(x= ndf['arrival_date_year'], y = ndf['adr'])
plt.xlabel("year",weight= 'bold')
plt.ylabel("Average daily rate" ,weight= 'bold')
plt.title("Average daily rate per year" ,weight= 'bold')
for bar in plots.patches:
  plots.annotate(format(bar.get_height(), '.1f'),(bar.get_x() + bar.get_width() / 2,bar.get_height()), ha='center', va='center',
                 size=10, xytext=(0, 6),textcoords='offset points')

# %% [markdown]
# there is a clear increase in the average daily rate every year.

# %%
plots = plt.figure(figsize=(15, 5)) 
x = ndf['arrival_date_month']
y = ndf['adr']
sns.barplot(x = x , y = y )
plt.xlabel("month", weight = 'bold')
plt.ylabel("Average daily rate", weight = 'bold')
plt.title("Average daily rate per month", weight = 'bold')
for bar in plots.patches:
  plots.annotate(format(bar.get_height(), '.1f'),(bar.get_x() + bar.get_width() / 2,bar.get_height()), ha='center', va='center',
                 size=10, xytext=(0, 6),textcoords='offset points')

# %% [markdown]
# Month of august each year show highest average daily rate, followed by june and july which might be due to the climatic conditions and vacations that makes it most preferrable time for the viivitors to hangout. A significant rise is seen in the months of september, april, may, october and march as well.

# %%
weekend_night = ndf.groupby('customer_type')['stays_in_weekend_nights'].value_counts().unstack().T
weekend_night
# Out:
# customer_type            Contract  Group  Transient  Transient-Party
# stays_in_weekend_nights
# 0                          1173.0  271.0    38319.0          12231.0
# 1                           913.0  160.0    23209.0           6343.0
# 2                          1402.0  132.0    25597.0           6177.0
# 3                           134.0    4.0      955.0            166.0
# 4                           436.0   10.0     1264.0            145.0
# 5                             1.0    NaN       67.0             11.0
# 6                             8.0    NaN      107.0             38.0
# 7                             4.0    NaN        9.0              6.0
# 8                             3.0    NaN       57.0              NaN
# 9                             NaN    NaN       10.0              1.0
# 10                            1.0    NaN        6.0              NaN
# 12                            1.0    NaN        3.0              1.0
# ...

# %%
sns.barplot(weekend_night)
plt.xlabel("type of customer", weight = 'bold')
plt.ylabel("weekend nights spent", weight = 'bold')
plt.title("weekend nights spent by each category of customers", weight = 'bold')
# Out:
# Text(0.5, 1.0, 'weekend nights spent by each category of customers')

# %%
week_night = ndf.groupby('customer_type')['stays_in_week_nights'].value_counts().unstack().T
week_night.dropna()
# Out:
# customer_type         Contract  Group  Transient  Transient-Party
# stays_in_week_nights
# 0                         90.0   84.0     6185.0           1286.0
# 1                        747.0  219.0    22259.0           7083.0
# 2                        914.0   89.0    24332.0           8348.0
# 3                        461.0   89.0    17119.0           4587.0
# 4                        243.0   24.0     7664.0           1632.0
# 5                        905.0   49.0     8462.0           1661.0
# 6                         94.0    6.0     1192.0            207.0
# 7                        147.0    5.0      758.0            119.0
# 8                        112.0    4.0      493.0             47.0
# 9                         17.0    1.0      193.0             20.0
# 10                       323.0    7.0      652.0             54.0

# %%
# plt.figure(figsize=(15, 5)) 
sns.distplot(week_night)
plt.xlabel("type of customer", weight = 'bold')
plt.ylabel("week nights spent", weight = 'bold')
plt.title("week nights spent by each category of customers", weight = 'bold')
# Out:
# C:\Users\Mokshda Sharma\AppData\Local\Temp\ipykernel_23560\1023857673.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(week_night)
# Text(0.5, 1.0, 'week nights spent by each category of customers')

# %%
plt.figure(figsize=(15, 7)) 
sns.boxenplot(x= ndf['market_segment'], y = ndf['lead_time'] )
plt.xlabel("market sector to which customer belongs", weight = 'bold')
plt.ylabel("lead time(Waiting days between the time of booking and time of arrival)", weight = 'bold')
plt.title("market sector of the customers as per lead time", weight = 'bold')
# Out:
# Text(0.5, 1.0, 'market sector of the customers as per lead time')

# %%
plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
sns.countplot(data = ndf,x = ndf['market_segment'],hue='hotel' ,palette='cool' ) 
plt.xlabel("market sectors", weight = 'bold')
plt.ylabel("customer count", weight = 'bold')
plt.xticks(rotation ='vertical')
plt.title("market sector to which customer belongs",fontweight="bold", size=10)
plt.subplot(1, 2, 2)
sns.countplot(data = ndf,y = ndf['distribution_channel'], hue='hotel', palette='rocket' )
plt.xlabel("customer count", weight = 'bold')
plt.ylabel("Distribution channel through which booking was made", weight = 'bold')
plt.title('Distribution channel through which booking was made',fontweight="bold", size=10)

plt.show()

# %%
table = pd.pivot_table(df, values=['adults','children','babies'], index=['meal'], aggfunc="sum")
table
# Out:
#            adults  babies  children
# meal
# BB         170280     690   10334.0
# FB           1563      24      78.0
# HB          27956     182    1747.0
# SC          19705      37     187.0
# Undefined    2132      16      57.0

# %%
plots = table.plot.bar()
plt.xlabel("customers on basis of age group", weight = 'bold')
plt.ylabel("preferrable meal type", weight = 'bold')
plt.title("meals preferred by customers of different age groups", weight = 'bold')
# for bar in plots.patches:
#   plots.annotate(format(bar.get_height(), '.1f'),(bar.get_x() + bar.get_width() / 2,bar.get_height()), ha='center', va='center',
#                  size=10, xytext=(0, 6),textcoords='offset points')
# Out:
# Text(0.5, 1.0, 'meals preferred by customers of different age groups')

# %% [markdown]
# Adults and childrens, both mostly preffers bed and breakfast type of meal. No particular type of meal is preferred by the babies, this may be due to their agr group.

# %%
ndf
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...
